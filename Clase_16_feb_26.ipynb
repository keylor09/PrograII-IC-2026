# %%
texto= "Juan viajar a colombia en \
el dia 24 del mes febrero del año2026, mientras que Ana viaja a Argentina \
para comprar 3 computadoras y 2 celulares"

# %%
texto
# Out:
# 'Juan viaja a colombia en el dia 24 del mes febrero del año2026, mientras que Ana viaja a Argentina para comprar 3 computadoras y 2 celulares'

# %%
palabras = texto.split()

# %%
palabras
# Out:
# ['Juan',
#  'viaja',
#  'a',
#  'colombia',
#  'en',
#  'el',
#  'dia',
#  '24',
#  'del',
#  'mes',
#  'febrero',
#  'del',
#  'año2026,',
#  'mientras',
#  'que',
#  'Ana',
#  'viaja',
#  'a',
#  'Argentina',
#  'para',
#  'comprar',
#  '3',
#  'computadoras',
#  'y',
#  '2',
#  'celulares']

# %%
# !pip -q install -U spacy && python -m spacy download es_core_news_sm -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 74.8 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
modeloIdioma =spacy.load('es_core_news_sm')

# %%
documento= modeloIdioma(texto)

# %%
[(ent.text,ent.label_) for ent in documento.ents if ent.label_=="PER"]
# Out:
# [('Juan', 'PER'), ('Ana', 'PER')]

# %%
[(ent.text,ent.label_) for ent in documento.ents if ent.label_ in ["GPE", "LOC"]]
# Out:
# [('colombia', 'LOC'), ('Argentina', 'LOC')]

# %%
[(t.text,t.lemma_,t.pos_) for t in documento if t.pos_=="VERB"]
# Out:
# [('viajar', 'viajar', 'VERB'),
#  ('viaja', 'viajar', 'VERB'),
#  ('comprar', 'comprar', 'VERB')]
